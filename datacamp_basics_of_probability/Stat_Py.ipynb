# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
plt.plot([-3, 0], [0,0], c ="grey")
plt.plot([0, 1], [0.5,0.5], c = 'grey')
plt.plot([1, 4], [1,1], c = 'grey')
plt.plot([0,0], [0, 0.5], '--', c="grey")
plt.plot([1,1], [0.5, 1.0], '--', c="grey")
plt.title("Функция распределения Бернулли")
plt.xlabel("x")
plt.ylabel("f(x)")
# Out:
# Text(0,0.5,'f(x)')

# %%
plt.plot([-3, 0], [0,0], c ="grey")
plt.plot([0, 1], [0.2,0.2], c = 'grey')
plt.plot([1, 2], [0.3,0.3], c = 'grey')
plt.plot([2, 3], [0.6,0.6], c = 'grey')
plt.plot([3, 4], [0.8,0.8], c = 'grey')
plt.plot([4, 7], [1,1], c = 'grey')
plt.plot([0,0], [0, 0.2], '--', c="grey")
plt.plot([1,1], [0.2, 0.3], '--', c="grey")
plt.plot([2,2], [0.3, 0.6], '--', c="grey")
plt.plot([3,3], [0.6, 0.8], '--', c="grey")
plt.plot([4,4], [0.8, 1], '--', c="grey")
plt.title("Функция Биномиального распределения")
plt.xlabel("x")
plt.ylabel("f(x)")
# Out:
# Text(0,0.5,'f(x)')

# %%
X = np.linspace(-10, 10, 1000)
y = (1/(np.sqrt(2*3.14))) * np.exp(-(X**2)/2)
plt.xlim(-5, 5)
plt.ylim(0, 0.45)

plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Плотность Нормального распределения')
plt.text(3.4,0.35, "$\mu$ = 0 \n$\sigma^2$ = 1", bbox={'facecolor':'white', 'alpha':0.5, 'pad':10, 'ec':'blue'})
plt.text(3.4,0.23, "$\mu$ = 1 \n$\sigma^2$ = 2", bbox={'facecolor':'white', 'alpha':0.5, 'pad':10, 'ec':'red'})
plt.plot(X, y, c='blue')
plt.plot(X, stats.norm.pdf(X, 1, np.sqrt(2)), color='red', lw=2, label = "3")
plt.plot([0,0], [0, 1],'--', c='grey')
plt.plot([1,1], [0, 1],'--', c='grey')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-140e687feacd> in <module>()
#      10 plt.text(3.4,0.23, "$\mu$ = 1 \n$\sigma^2$ = 2", bbox={'facecolor':'white', 'alpha':0.5, 'pad':10, 'ec':'red'})
#      11 plt.plot(X, y, c='blue')
# ---> 12 plt.plot(X, stats.norm.pdf(X, 1, np.sqrt(2)), color='red', lw=2, label = "3")
#      13 plt.plot([0,0], [0, 1],'--', c='grey')
#      14 plt.plot([1,1], [0, 1],'--', c='grey')
#
# NameError: name 'stats' is not defined

# %%
X = np.linspace(-10, 10, 1000)
y = 1 / (2 + X**2)**1.5
plt.xlim(-5, 5)
plt.ylim(0, 0.45)

plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Плотность распределения Стьюдента')
plt.plot(X, y, c='grey')

# %%
import scipy.stats as stats

X = np.linspace(-10, 10, 1000)
plt.xlim(-5, 5)
plt.plot(X, stats.t.pdf(X, df=2), color='red', lw=2, label = 'n = 2')
plt.plot(X, stats.t.pdf(X, df=5), color='green', lw=2, label = 'n = 5')
plt.plot(X, stats.t.pdf(X, df=30), color='blue', lw=2, label = 'n = 30')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Плотность распределения Стьюдента')
plt.legend()
plt.show()

# %%
import scipy.stats as stats

x = np.arange(0, 30, .05)
plt.xlim(0, 30)
plt.plot(x, stats.chi2.pdf(x, df=2), color='red', lw=2, label = 'n = 2')
plt.plot(x, stats.chi2.pdf(x, df=3), color='green', lw=2, label = 'n = 3')
plt.plot(x, stats.chi2.pdf(x, df=10), color='blue', lw=2, label = 'n = 10')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Плотность распределения Хи-квадрат')
plt.legend()
plt.show()

# %%
import scipy.stats as stats

X = np.linspace(-10, 10, 1000)
plt.xlim(-5, 5)
plt.ylim(0,1)
plt.plot(X, stats.norm.pdf(X, 0, np.sqrt(0.2)), color='red', lw=2, label = "1")
plt.plot(X, stats.norm.pdf(X, 0, np.sqrt(5)), color='green', lw=2, label = "2")
plt.plot(X, stats.norm.pdf(X, 2, np.sqrt(0.5)), color='blue', lw=2, label = "3")
plt.plot([0,0], [0,1], "--", c="grey")
plt.plot([2,2], [0,1], "--", c="grey")
plt.legend()

# %%
def rstyle(ax): 
    """Styles an axes to appear like ggplot2
    Must be called after all plot and axis manipulation operations have been carried out (needs to know final tick spacing)
    """
    #set the style of the major and minor grid lines, filled blocks
    ax.grid(True, 'major', color='w', linestyle='-', linewidth=1.4)
    ax.grid(True, 'minor', color='0.92', linestyle='-', linewidth=0.7)
    ax.patch.set_facecolor('0.85')
    ax.set_axisbelow(True)
    
    #set minor tick spacing to 1/2 of the major ticks
    ax.xaxis.set_minor_locator(MultipleLocator( (plt.xticks()[0][1]-plt.xticks()[0][0]) / 2.0 ))
    ax.yaxis.set_minor_locator(MultipleLocator( (plt.yticks()[0][1]-plt.yticks()[0][0]) / 2.0 ))
    
    #remove axis border
    for child in ax.get_children():
        if isinstance(child, matplotlib.spines.Spine):
            child.set_alpha(0)
       
    #restyle the tick lines
    for line in ax.get_xticklines() + ax.get_yticklines():
        line.set_markersize(5)
        line.set_color("gray")
        line.set_markeredgewidth(1.4)
    
    #remove the minor tick lines    
    for line in ax.xaxis.get_ticklines(minor=True) + ax.yaxis.get_ticklines(minor=True):
        line.set_markersize(0)
    
    #only show bottom left ticks, pointing out of axis
    rcParams['xtick.direction'] = 'out'
    rcParams['ytick.direction'] = 'out'
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    
    
    if ax.legend_ != None:
        lg = ax.legend_
        lg.get_frame().set_linewidth(0)
        lg.get_frame().set_alpha(0.5)

# %%
from pylab import *
import scipy.stats

t = arange(0.0, 100.0, 0.1)
s = sin(0.1*pi*t)*exp(-t*0.01)
fig = plt.figure()
ax = fig.add_subplot(111)

plot(t,s, label = "Original")
plot(t,s*2, label = "Doubled")

ax.legend()
rstyle(ax)
plt.show()
